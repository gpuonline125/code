# %%
import sys                      # System bindings
import cv2                      # OpenCV bindings
import numpy as np
from collections import Counter


class BackgroundColorDetector():
    def __init__(self, imageLoc):
        self.img = cv2.imread(imageLoc, 1)
        self.manual_count = {}
        self.w, self.h, self.channels = self.img.shape
        self.total_pixels = self.w*self.h

    def count(self):
        for y in range(0, self.h):
            for x in range(0, self.w):
                RGB = (self.img[x, y, 2], self.img[x, y, 1], self.img[x, y, 0])
                if RGB in self.manual_count:
                    self.manual_count[RGB] += 1
                else:
                    self.manual_count[RGB] = 1

    def detect(self):
        self.count()
        return Counter(self.manual_count)


BackgroundColor = BackgroundColorDetector('b1.png')
a = BackgroundColor.detect()
w = a[255, 255, 255]
b = a[0,0,0]
if w > b:
  print('white')
else:
  print('black')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1-7ddf1a87e241> in <module>()
#      26
#      27
# ---> 28 BackgroundColor = BackgroundColorDetector('b1.png')
#      29 a = BackgroundColor.detect()
#      30 w = a[255, 255, 255]
#
# <ipython-input-1-7ddf1a87e241> in __init__(self, imageLoc)
#       9         self.img = cv2.imread(imageLoc, 1)
#      10         self.manual_count = {}
# ---> 11         self.w, self.h, self.channels = self.img.shape
#      12         self.total_pixels = self.w*self.h
#      13
#
# AttributeError: 'NoneType' object has no attribute 'shape'
